# %%
import numpy as np
import pandas as pd
import statistics as stat
f1=pd.read_csv("ML101_train_dataset.csv")
cols=['Average Daily Steps','Hours of Sleep','Calorie Intake','Height','Weight','Cholestrol level','Blood Sugar','Age','Gender','Systolic BP','Diastolic BP',"lifeSTyle"]
def processed(arr):
    data=arr
    mean=np.mean(data)
    median=np.median(data)
    mode=stat.mode(data)
    return mean,median,mode
M= f1.groupby('Gender').get_group('Male')
F= f1.groupby('Gender').get_group('Female')
# Out:
#        Average Daily Steps  Hours of Sleep  Caloric Intake   Age Gender  \
# 0                  15725.0        6.518042          1714.0  56.0   Male
# 2                   7424.0        4.856772          1366.0  46.0   Male
# 5                  16484.0        4.380561          2373.0  25.0   Male
# 9                   2798.0        7.573938          1377.0  75.0   Male
# 10                  3700.0        4.029191          3559.0  36.0   Male
# ...                    ...             ...             ...   ...    ...
# 99994               2701.0             NaN          2376.0  41.0   Male
# 99995               2265.0             NaN          2030.0  53.0   Male
# 99996              10959.0        9.661165          2233.0  22.0   Male
# 99997                  NaN        7.378317          2080.0  37.0   Male
# 99999              18618.0        9.301179          3458.0  37.0   Male
#
#            Height     Weight  Cholesterol level  Blood Sugar level  \
# ...
